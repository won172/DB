# %% [markdown]
# # 주가 예측 모델 구축

# %% [markdown]
# ## 1. 데이터 불러오기

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout, BatchNormalization, LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import GlorotNormal
from tensorflow.keras import regularizers

# %%
esgu = pd.read_csv('../데이터셋/ESGU.csv', encoding='cp949')
erth = pd.read_csv('../데이터셋/^GSPC.csv', encoding='cp949')
vde = pd.read_csv('../데이터셋/VDE.csv', encoding='cp949')
nulg = pd.read_csv('../데이터셋/NULG.csv', encoding='cp949')
tan = pd.read_csv('../데이터셋/TAN.csv', encoding='cp949')
susa = pd.read_csv('../데이터셋/SUSA.csv', encoding='cp949')

# 전통 에너지 관련 주가 데이터
xom = pd.read_csv('../데이터셋/XOM.csv')
eog = pd.read_csv('../데이터셋/EOG.csv')
mpc = pd.read_csv('../데이터셋/MPC.csv')
kmi = pd.read_csv('../데이터셋/KMI.csv')
btu = pd.read_csv('../데이터셋/BTU.csv')

# 친환경 에너지 관련 주가 데이터
nee = pd.read_csv('../데이터셋/NEE.csv')
fslr = pd.read_csv('../데이터셋/FSLR.csv')
enph = pd.read_csv('../데이터셋/ENPH.csv')
run = pd.read_csv('../데이터셋/RUN.csv')

# %% [markdown]
# ## 2. 뉴스 감성 점수 병합

# %%
# 뉴스 감성 점수 데이터 로드 (이전에 감성 분석한 결과)
news_df = pd.read_csv("../데이터셋/news_sentiment_analysis.csv")

# 날짜 정리
news_df['Date'] = pd.to_datetime(news_df['Date'])

# 날짜별 평균 감성 점수 계산
news_sentiment = news_df.groupby('Date')['Sentiment_Score'].mean().reset_index()

# %% [markdown]
# ## 3. 전처리

# %%
def stock_pre(df):
    # 7번째 행 삭제
    df.drop(df.columns[6], axis=1, inplace=True)
    # 열 이름 통일
    new_columns = ['Date', 'Close', 'Open', 'High', 'Low', 'Volume']
    df.columns = new_columns
    # 날짜로 정렬
    df.sort_values('Date',ascending=True, inplace=True)
    df.reset_index(drop=True, inplace=True)
    
    df['Date'] = pd.to_datetime(df['Date'])  # 날짜 형식 변환
    df = df.merge(news_sentiment, on='Date', how='left')  # 새로운 데이터프레임이 생성되지만, 원본은 변경되지 않음
    df['Sentiment_Score'].fillna(0, inplace=True)

    # 시작 날짜와 종료 날짜를 설정
    start = '2016-01-01'
    end = '2025-02-01'

    # 이 기간 동안의 데이터만 필터링
    df = df[(df['Date'] >= start) & (df['Date'] <= end)]
    
    df.index = df["Date"]
    df.drop("Date", axis = 1, inplace = True)
    df

    # bfill로 결측값 채우기
    df.bfill(axis=0, inplace=True)  # 행 방향으로 결측값 채우기
    # ffill로 결측값 채우기
    df.ffill(axis=0, inplace=True)  # 행 방향으로 결측값 채우기
    return df

# %%
tan = stock_pre(tan)

# %% [markdown]
# ## 4. 모델

# %%
TARGET = "Close"
SEQ_SIZE = 50
PRED_SIZE = 1
EPOCH = 30
BATCH_SIZE = 32

def split_xy(dataset, time_steps, y_column):
    x, y = [], []
    for i in range(len(dataset) - time_steps - y_column):
        x_end_number = i + time_steps
        y_end_number = x_end_number + y_column
        x.append(dataset.iloc[i:x_end_number, :].values)
        y.append(dataset.iloc[x_end_number:y_end_number, :][TARGET].values)
    return np.array(x), np.array(y)

X, y = split_xy(tan, SEQ_SIZE, PRED_SIZE)
print(X[0], "\n", y[0])
print("X size:", X.shape)
print("y size:", y.shape)
# Out:
# [[ 2.83203945e+01  2.83203945e+01  2.72619466e+01  2.76577127e+01
#    2.22400000e+05  0.00000000e+00]
#  [ 2.78878117e+01  2.88082015e+01  2.78141805e+01  2.85873082e+01
#    2.18900000e+05  0.00000000e+00]
#  [ 2.73447819e+01  2.77037351e+01  2.71146844e+01  2.73815983e+01
#    4.02900000e+05  0.00000000e+00]
#  [ 2.48413220e+01  2.64980247e+01  2.46940597e+01  2.64059854e+01
#    4.48300000e+05  0.00000000e+00]
#  [ 2.51266460e+01  2.58261427e+01  2.50346085e+01  2.57525115e+01
#    2.19400000e+05  0.00000000e+00]
#  [ 2.42246628e+01  2.53935584e+01  2.39761571e+01  2.52462962e+01
#    2.25100000e+05  0.00000000e+00]
#  [ 2.37000389e+01  2.50069926e+01  2.34331250e+01  2.48137098e+01
#    3.50600000e+05  0.00000000e+00]
#  [ 2.28716888e+01  2.44271482e+01  2.26876102e+01  2.40681950e+01
#    2.23700000e+05  0.00000000e+00]
#  [ 2.30189514e+01  2.31478054e+01  2.20985615e+01  2.28624851e+01
#    2.22500000e+05  0.00000000e+00]
#  [ 2.16475697e+01  2.20525399e+01  2.09664814e+01  2.17948319e+01
#    2.48100000e+05  0.00000000e+00]
#  [ 2.12425976e+01  2.23286579e+01  2.09664813e+01  2.21629874e+01
#    3.12500000e+05  0.00000000e+00]
#  [ 2.13346405e+01  2.14726987e+01  1.97883850e+01  2.05523087e+01
#    1.84700000e+05  0.00000000e+00]
#  [ 2.15923481e+01  2.20341366e+01  2.10401155e+01  2.12886195e+01
#    1.69700000e+05  0.00000000e+00]
#  [ 2.24206982e+01  2.27612414e+01  2.20893572e+01  2.22458236e+01
#    1.69200000e+05  0.00000000e+00]
#  [ 2.18224449e+01  2.24759227e+01  2.18132426e+01  2.24206998e+01
#    7.58000000e+04  0.00000000e+00]
#  [ 2.29177055e+01  2.30097449e+01  2.16291602e+01  2.19144805e+01
#    2.41400000e+05  0.00000000e+00]
#  [ 2.26599998e+01  2.31938259e+01  2.24483088e+01  2.26784063e+01
#    1.62300000e+05  0.00000000e+00]
#  [ 2.27060204e+01  2.30925842e+01  2.22918442e+01  2.27796515e+01
#    7.48000000e+04 -6.21351182e-01]
#  [ 2.32030296e+01  2.33134772e+01  2.27888552e+01  2.27980593e+01
#    6.36000000e+04  0.00000000e+00]
#  [ 2.30373592e+01  2.31846215e+01  2.25679602e+01  2.29729305e+01
#    5.24000000e+04  0.00000000e+00]
#  [ 2.21537819e+01  2.30281529e+01  2.20065197e+01  2.30281529e+01
#    9.18000000e+04  0.00000000e+00]
#  [ 2.23654728e+01  2.24483080e+01  2.15739387e+01  2.23838810e+01
#    8.55000000e+04  0.00000000e+00]
#  [ 2.26231842e+01  2.30097480e+01  2.24114949e+01  2.24391055e+01
#    6.37000000e+04  0.00000000e+00]
#  [ 2.20341320e+01  2.25587539e+01  2.19789074e+01  2.25587539e+01
#    7.32000000e+04  0.00000000e+00]
#  [ 2.08192215e+01  2.15279204e+01  2.04786764e+01  2.13806582e+01
#    8.98000000e+04  0.00000000e+00]
#  [ 2.04786739e+01  2.07824025e+01  2.00552954e+01  2.04050428e+01
#    1.51200000e+05  0.00000000e+00]
#  [ 1.96779347e+01  2.01565378e+01  1.96779347e+01  1.97423634e+01
#    1.79100000e+05  0.00000000e+00]
#  [ 1.87299347e+01  1.92729649e+01  1.84538167e+01  1.90796821e+01
#    2.15700000e+05  0.00000000e+00]
#  [ 1.88035641e+01  1.93281860e+01  1.84077962e+01  1.90704762e+01
#    1.00700000e+05  0.00000000e+00]
#  [ 1.99448471e+01  2.00921093e+01  1.93742047e+01  1.94018170e+01
#    1.73100000e+05  0.00000000e+00]
#  [ 2.05154896e+01  2.07824017e+01  2.01841487e+01  2.03037986e+01
#    1.31800000e+05  0.00000000e+00]
#  [ 2.05246944e+01  2.08284231e+01  2.03406175e+01  2.08192207e+01
#    8.35000000e+04  0.00000000e+00]
#  [ 2.01289272e+01  2.03866353e+01  2.00460920e+01  2.03866353e+01
#    6.81000000e+04  0.00000000e+00]
#  [ 2.05523052e+01  2.08652379e+01  2.04142471e+01  2.04142471e+01
#    9.26000000e+04  0.00000000e+00]
#  [ 2.02301693e+01  2.05983249e+01  2.01749464e+01  2.05983249e+01
#    3.95000000e+04  0.00000000e+00]
#  [ 2.07547951e+01  2.08192239e+01  1.97607739e+01  1.99908714e+01
#    8.07000000e+04  0.00000000e+00]
#  [ 2.08468304e+01  2.08468304e+01  2.02025585e+01  2.06811599e+01
#    5.40000000e+04  0.00000000e+00]
#  [ 2.12794132e+01  2.15923441e+01  2.11873739e+01  2.14174713e+01
#    8.20000000e+04  0.00000000e+00]
#  [ 2.15831432e+01  2.19144824e+01  2.13254334e+01  2.15095121e+01
#    4.45000000e+04  0.00000000e+00]
#  [ 2.14542866e+01  2.16383652e+01  2.11689662e+01  2.16383652e+01
#    1.00700000e+05  0.00000000e+00]
#  [ 2.20525398e+01  2.20709480e+01  2.13346369e+01  2.14726950e+01
#    9.85000000e+04  0.00000000e+00]
#  [ 2.19512978e+01  2.20341330e+01  2.16751798e+01  2.19512978e+01
#    9.17000000e+04  0.00000000e+00]
#  [ 2.21998043e+01  2.25495517e+01  2.20065215e+01  2.21998043e+01
#    9.44000000e+04  0.00000000e+00]
#  [ 2.27152214e+01  2.27980566e+01  2.23102494e+01  2.23102494e+01
#    6.65000000e+04  0.00000000e+00]
#  [ 2.21906014e+01  2.29361167e+01  2.21445808e+01  2.29361167e+01
#    8.16000000e+04  0.00000000e+00]
#  [ 2.24206982e+01  2.24943293e+01  2.21998048e+01  2.24851252e+01
#    3.09000000e+04  0.00000000e+00]
#  [ 2.20617447e+01  2.25403478e+01  2.19236866e+01  2.25403478e+01
#    1.95800000e+05  0.00000000e+00]
#  [ 2.25955696e+01  2.26047737e+01  2.22090058e+01  2.24667156e+01
#    6.83000000e+04  0.00000000e+00]
#  [ 2.25771637e+01  2.27152218e+01  2.23286580e+01  2.25219390e+01
#    5.24000000e+04  0.00000000e+00]
#  [ 2.23470669e+01  2.23562710e+01  2.20433383e+01  2.23562710e+01
#    6.03000000e+04  0.00000000e+00]]
#  [22.47592163]
# X size: (2233, 50, 6)
# y size: (2233, 1)

# %%
# 시퀀스별로 Min-Max 정규화
scaler = MinMaxScaler()
X_reshaped = X.reshape(-1, X.shape[-1])
X_scaled = scaler.fit_transform(X_reshaped).reshape(X.shape)
y_scaled = scaler.fit_transform(y)

# train, test 분리
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3, random_state=42)

# %% [markdown]
# ### 4.1 GRU

# %%
# 초기화 함수 정의
initializer = GlorotNormal()

# 모델 구성
model = Sequential()
model.add(BatchNormalization())
model.add(GRU(128, input_shape=(SEQ_SIZE, X_train.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(GRU(64, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu', kernel_initializer=initializer, kernel_regularizer=regularizers.l2(0.002)))
model.add(Dense(1))
optimizer = Adam(learning_rate=0.001)

model.compile(optimizer=optimizer, loss='mean_squared_error')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=EPOCH, validation_split=0.2, batch_size=BATCH_SIZE, callbacks=[early_stopping])

# 모델 평가
loss = model.evaluate(X_test, y_test)
print(f'테스트 손실: {loss}')

# 예측
y_pred = model.predict(X_test)
# Out:
# Epoch 1/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - loss: 0.3555 - val_loss: 0.1607
# Epoch 2/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.1336 - val_loss: 0.1634
# Epoch 3/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.1047 - val_loss: 0.1516
# Epoch 4/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0935 - val_loss: 0.1275
# Epoch 5/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0840 - val_loss: 0.1158
# Epoch 6/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0780 - val_loss: 0.0984
# Epoch 7/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0727 - val_loss: 0.0889
# Epoch 8/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0711 - val_loss: 0.0691
# Epoch 9/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0666 - val_loss: 0.0623
# Epoch 10/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0628 - val_loss: 0.0557
# Epoch 11/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0583 - val_loss: 0.0534
# Epoch 12/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0581 - val_loss: 0.0523
# Epoch 13/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0532 - val_loss: 0.0480
# Epoch 14/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0502 - val_loss: 0.0443
# Epoch 15/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0483 - val_loss: 0.0415
# Epoch 16/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0453 - val_loss: 0.0392
# Epoch 17/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0417 - val_loss: 0.0373
# Epoch 18/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0404 - val_loss: 0.0350
# Epoch 19/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0380 - val_loss: 0.0332
# Epoch 20/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0357 - val_loss: 0.0314
# Epoch 21/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0341 - val_loss: 0.0294
# Epoch 22/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0318 - val_loss: 0.0279
# Epoch 23/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0295 - val_loss: 0.0258
# Epoch 24/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0279 - val_loss: 0.0281
# Epoch 25/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0265 - val_loss: 0.0229
# Epoch 26/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0251 - val_loss: 0.0217
# Epoch 27/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0245 - val_loss: 0.0201
# Epoch 28/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0228 - val_loss: 0.0189
# Epoch 29/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0211 - val_loss: 0.0189
# Epoch 30/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0212 - val_loss: 0.0166
# Restoring model weights from the end of the best epoch: 30.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0166
# 테스트 손실: 0.016542496159672737
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step

# %%
# 성능 평가 지표
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'MSE: {round(mse, 4)}')
print(f'MAE: {round(mae, 4)}')
# Out:
# MSE: 0.0007
# MAE: 0.0182

# %%
# 시각화
plt.figure(figsize=(36, 20))
plt.plot(y_test[100:300].flatten(), label='Actual')
plt.plot(y_pred[100:300].flatten(), label='Predicted')
plt.legend()
plt.title('Actual vs Predicted')
plt.show()

# 학습 곡선 시각화
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### 4.2 LSTM

# %%
# 시퀀스별로 Min-Max 정규화
scaler = MinMaxScaler()
X_reshaped = X.reshape(-1, X.shape[-1])
X_scaled = scaler.fit_transform(X_reshaped).reshape(X.shape)
y_scaled = scaler.fit_transform(y)


# train, test 분리
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# 초기화 함수 정의
initializer = GlorotNormal()

# 모델 구성
model2 = Sequential()
model2.add(LSTM(128, input_shape=(SEQ_SIZE, X_train.shape[2]), return_sequences=True))
model2.add(Dropout(0.2))
model2.add(LSTM(64, return_sequences=False))
model2.add(Dropout(0.2))
model2.add(Dense(32, activation='relu', kernel_initializer=initializer, kernel_regularizer=regularizers.l2(0.002)))
model2.add(Dense(1))
optimizer = Adam(learning_rate=0.001)

model2.compile(optimizer=optimizer, loss='mean_squared_error')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
history = model2.fit(X_train, y_train, epochs=EPOCH, validation_split=0.2, batch_size=BATCH_SIZE, callbacks=[early_stopping])

# 모델 평가
loss = model2.evaluate(X_test, y_test)
print(f'테스트 손실: {loss}')

# 예측
y_pred = model2.predict(X_test)
# Out:
# Epoch 1/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.1177 - val_loss: 0.0646
# Epoch 2/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0621 - val_loss: 0.0473
# Epoch 3/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0450 - val_loss: 0.0353
# Epoch 4/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0332 - val_loss: 0.0244
# Epoch 5/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0235 - val_loss: 0.0179
# Epoch 6/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0174 - val_loss: 0.0130
# Epoch 7/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0130 - val_loss: 0.0097
# Epoch 8/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0095 - val_loss: 0.0073
# Epoch 9/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0077 - val_loss: 0.0057
# Epoch 10/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0060 - val_loss: 0.0045
# Epoch 11/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0048 - val_loss: 0.0042
# Epoch 12/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0040 - val_loss: 0.0034
# Epoch 13/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 14/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0033 - val_loss: 0.0022
# Epoch 15/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 16/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 17/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 18/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 19/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 20/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 21/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 22/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 23/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 24/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0017 - val_loss: 0.0010
# Epoch 25/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 26/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0013 - val_loss: 8.9320e-04
# Epoch 27/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0015 - val_loss: 8.6266e-04
# Epoch 28/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0012 - val_loss: 9.0442e-04
# Epoch 29/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 30/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0014 - val_loss: 9.8424e-04
# Restoring model weights from the end of the best epoch: 27.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.2014e-04
# 테스트 손실: 0.0008314070291817188
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step

# %%
# 성능 평가 지표
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'MSE: {round(mse, 4)}')
print(f'MAE: {round(mae, 4)}')
# Out:
# MSE: 0.0005
# MAE: 0.0152

# %%
# 시각화
plt.figure(figsize=(36, 20))
plt.plot(y_test.flatten(), label='Actual')
plt.plot(y_pred.flatten(), label='Predicted')
plt.legend()
plt.title('Actual vs Predicted')
plt.show()

# 학습 곡선 시각화
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## 5. 최종 모델 선정

# %% [markdown]
# MSE 값을 비교한 결과, LSTM의 성능이 더 좋은 것으로 보임.

# %%
# 테스트 데이터 예측
predicted_price = model2.predict(X_test)

# 원래 스케일로 변환
predicted_price = scaler.inverse_transform(predicted_price.reshape(-1, 1))
real_price = scaler.inverse_transform(y_test.reshape(-1, 1))

# 예측 결과 시각화
plt.figure(figsize=(36,20))
plt.plot(real_price, label='Actual Price')
plt.plot(predicted_price, label='Predicted Price')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
print(X_train.shape)  # (samples, SEQ_SIZE, features)
# Out:
# (1786, 50, 6)

# %%
future_days = 300  # 예측하고 싶은 미래 일 수
future_prices = []

recent_data = X_scaled[-SEQ_SIZE:].reshape(50, SEQ_SIZE, X_train.shape[2])

for i in range(future_days):
    predicted_price = model2.predict(recent_data)  # 하루 예측
    future_prices.append(predicted_price[0][0])  # 결과 저장

    # 예측된 값을 feature 차원에 맞춰 변환
    predicted_value = np.full((50, 1, X_train.shape[2]), predicted_price[0][0])  

    # 최근 데이터를 업데이트 (Sliding Window 방식)
    new_data = np.append(recent_data[:, 1:, :], predicted_value, axis=1)
    recent_data = new_data  # 최신 데이터로 갱신

# 원래 가격으로 변환
future_prices = scaler.inverse_transform(np.array(future_prices).reshape(-1, 1))
print(f"예측된 미래 {future_days}일 주가: {future_prices.flatten()}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 예측된 미래 300일 주가: [36.726852 36.49588  36.52063  36.760647 37.176064 37.730648 38.39368
#  39.140224 39.925846 40.75247  41.61222  42.496555 43.38482  44.274475
#  45.17228  46.075172 46.981102 47.888752 48.79735  49.706493 50.616035
#  51.52606  52.436794 53.32671  54.1719   55.01106  55.840958 56.659557
#  57.465744 58.25898  59.03923  59.806694 60.561775 61.304947 62.036774
#  62.757744 63.468517 64.169556 64.8614   65.54456  66.21953  66.88681
#  67.54697  68.186325 68.7812   69.36356  69.931175 70.48234  71.01627
#  71.53256  72.03133  72.51278  72.97729  73.42532  73.857346 74.273865
#  74.675354 75.062325 75.43524  75.794586 76.14081  76.47436  76.79569
#  77.10522  77.40336  77.69054  77.96713  78.233536 78.49013  78.73725
#  78.97528  79.20454  79.42533  79.63801  79.84284  80.04012  80.23015
#  80.41317  80.58945  80.75923  80.92277  81.08028  81.23198  81.3781
#  81.51884  81.65439  81.78494  81.91067  82.03178  82.14841  82.260735
#  82.36892  82.47311  82.57344  82.670074 82.76314  82.85277  82.93907
#  83.02218  83.10222  83.1793   83.25351  83.32498  83.3938   83.46007
#  83.52389  83.58533  83.64449  83.701454 83.7563   83.80911  83.85996
#  83.90892  83.956055 84.00144  84.045135 84.0872   84.1277   84.16667
#  84.20422  84.24036  84.27515  84.30863  84.34087  84.3719   84.40179
#  84.43055  84.45824  84.484886 84.51055  84.53524  84.55902  84.58191
#  84.60393  84.62513  84.64555  84.66519  84.68409  84.7023   84.71982
#  84.73669  84.752914 84.76853  84.78356  84.798035 84.81197  84.82538
#  84.83829  84.8507   84.86265  84.87415  84.88524  84.89589  84.90615
#  84.916016 84.925514 84.93466  84.94346  84.95192  84.960075 84.967926
#  84.97547  84.98274  84.98974  84.99646  85.00294  85.00918  85.015175
#  85.02094  85.026505 85.03185  85.036995 85.04194  85.046715 85.05129
#  85.05571  85.05996  85.06404  85.06798  85.071754 85.07541  85.0789
#  85.08228  85.085526 85.08865  85.09166  85.09455  85.097336 85.100006
#  85.1026   85.10507  85.10746  85.10976  85.11197  85.114105 85.11616
#  85.118126 85.12002  85.12185  85.1236   85.12529  85.12692  85.12848
#  85.12998  85.13143  85.132835 85.13418  85.13547  85.13671  85.1379
#  85.13905  85.14016  85.14123  85.14225  85.14324  85.14419  85.1451
#  85.14598  85.146835 85.147644 85.14842  85.14918  85.14991  85.15061
#  85.151276 85.15192  85.15255  85.153145 85.15372  85.154274 85.15481
#  85.15532  85.15581  85.15629  85.156746 85.15719  85.157616 85.15802
#  85.15842  85.15879  85.15916  85.1595   85.15984  85.16017  85.16048
#  85.160774 85.16107  85.16135  85.16161  85.16188  85.16212  85.16235
#  85.16258  85.16281  85.163025 85.16322  85.16342  85.163605 85.163795
#  85.16397  85.16414  85.16431  85.16446  85.16462  85.16476  85.164894
#  85.16503  85.16516  85.16528  85.16541  85.16552  85.165634 85.16573
#  85.16584  85.16594  85.16603  85.166115 85.166214 85.16628  85.16637
#  85.16644  85.16652  85.166595 85.16666  85.16673  85.16679  85.166855
#  85.16691  85.16697  85.16702  85.16708  85.16712  85.16718  85.16722
#  85.167274 85.16732  85.16736  85.1674   85.16745  85.16748 ]

# %%
print('50일 뒤 가격:', future_prices[49])
print('100일 뒤 가격:', future_prices[99])
print('200일 뒤 가격:', future_prices[199])
print('300일 뒤 가격:', future_prices[299])
# Out:
# 50일 뒤 가격: [71.53256]
# 100일 뒤 가격: [83.10222]
# 200일 뒤 가격: [85.1236]
# 300일 뒤 가격: [85.16748]
