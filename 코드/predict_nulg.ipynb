# %% [markdown]
# # 주가 예측 모델 구축

# %% [markdown]
# ## 1. 데이터 불러오기

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout, BatchNormalization, LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import GlorotNormal
from tensorflow.keras import regularizers

# %%
esgu = pd.read_csv('../데이터셋/ESGU.csv', encoding='cp949')
erth = pd.read_csv('../데이터셋/^GSPC.csv', encoding='cp949')
vde = pd.read_csv('../데이터셋/VDE.csv', encoding='cp949')
nulg = pd.read_csv('../데이터셋/NULG.csv', encoding='cp949')
tan = pd.read_csv('../데이터셋/TAN.csv', encoding='cp949')
susa = pd.read_csv('../데이터셋/SUSA.csv', encoding='cp949')

# 전통 에너지 관련 주가 데이터
xom = pd.read_csv('../데이터셋/XOM.csv')
eog = pd.read_csv('../데이터셋/EOG.csv')
mpc = pd.read_csv('../데이터셋/MPC.csv')
kmi = pd.read_csv('../데이터셋/KMI.csv')
btu = pd.read_csv('../데이터셋/BTU.csv')

# 친환경 에너지 관련 주가 데이터
nee = pd.read_csv('../데이터셋/NEE.csv')
fslr = pd.read_csv('../데이터셋/FSLR.csv')
enph = pd.read_csv('../데이터셋/ENPH.csv')
run = pd.read_csv('../데이터셋/RUN.csv')

# %% [markdown]
# ## 2. 뉴스 감성 점수 병합

# %%
# 뉴스 감성 점수 데이터 로드 (이전에 감성 분석한 결과)
news_df = pd.read_csv("../데이터셋/news_sentiment_analysis.csv")

# 날짜 정리
news_df['Date'] = pd.to_datetime(news_df['Date'])

# 날짜별 평균 감성 점수 계산
news_sentiment = news_df.groupby('Date')['Sentiment_Score'].mean().reset_index()

# %% [markdown]
# ## 3. 전처리

# %%
def stock_pre(df):
    # 7번째 행 삭제
    df.drop(df.columns[6], axis=1, inplace=True)
    # 열 이름 통일
    new_columns = ['Date', 'Close', 'Open', 'High', 'Low', 'Volume']
    df.columns = new_columns
    # 날짜로 정렬
    df.sort_values('Date',ascending=True, inplace=True)
    df.reset_index(drop=True, inplace=True)
    
    df['Date'] = pd.to_datetime(df['Date'])  # 날짜 형식 변환
    df = df.merge(news_sentiment, on='Date', how='left')  # 새로운 데이터프레임이 생성되지만, 원본은 변경되지 않음
    df['Sentiment_Score'].fillna(0, inplace=True)

    # 시작 날짜와 종료 날짜를 설정
    start = '2016-01-01'
    end = '2025-02-01'

    # 이 기간 동안의 데이터만 필터링
    df = df[(df['Date'] >= start) & (df['Date'] <= end)]
    
    df.index = df["Date"]
    df.drop("Date", axis = 1, inplace = True)
    df

    # bfill로 결측값 채우기
    df.bfill(axis=0, inplace=True)  # 행 방향으로 결측값 채우기
    # ffill로 결측값 채우기
    df.ffill(axis=0, inplace=True)  # 행 방향으로 결측값 채우기
    return df

# %%
nulg = stock_pre(nulg)

# %% [markdown]
# ## 4. 모델

# %%
TARGET = "Close"
SEQ_SIZE = 50
PRED_SIZE = 1
EPOCH = 30
BATCH_SIZE = 32

def split_xy(dataset, time_steps, y_column):
    x, y = [], []
    for i in range(len(dataset) - time_steps - y_column):
        x_end_number = i + time_steps
        y_end_number = x_end_number + y_column
        x.append(dataset.iloc[i:x_end_number, :].values)
        y.append(dataset.iloc[x_end_number:y_end_number, :][TARGET].values)
    return np.array(x), np.array(y)

X, y = split_xy(nulg, SEQ_SIZE, PRED_SIZE)
print(X[0], "\n", y[0])
print("X size:", X.shape)
print("y size:", y.shape)
# Out:
# [[ 2.18514938e+01  2.18514938e+01  2.18514938e+01  2.18514938e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.18376331e+01  2.18462974e+01  2.18203013e+01  2.18376331e+01
#    6.00000000e+02  5.17575383e-01]
#  [ 2.18376331e+01  2.18376331e+01  2.18376331e+01  2.18376331e+01
#    1.00000000e+02  0.00000000e+00]
#  [ 2.18376331e+01  2.18376331e+01  2.18376331e+01  2.18376331e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.18376331e+01  2.18376331e+01  2.18376331e+01  2.18376331e+01
#    1.00000000e+02  0.00000000e+00]
#  [ 2.18376331e+01  2.18376331e+01  2.18376331e+01  2.18376331e+01
#    1.00000000e+02  0.00000000e+00]
#  [ 2.18376331e+01  2.18376331e+01  2.18376331e+01  2.18376331e+01
#    0.00000000e+00 -9.98905271e-01]
#  [ 2.18376331e+01  2.18376331e+01  2.18376331e+01  2.18376331e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.18376331e+01  2.18376331e+01  2.18376331e+01  2.18376331e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.18376331e+01  2.18376331e+01  2.18376331e+01  2.18376331e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.18376331e+01  2.18376331e+01  2.18376331e+01  2.18376331e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.18376331e+01  2.18376331e+01  2.18376331e+01  2.18376331e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.18376331e+01  2.18376331e+01  2.18376331e+01  2.18376331e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.21236019e+01  2.21236019e+01  2.21236019e+01  2.21236019e+01
#    1.10000000e+03  0.00000000e+00]
#  [ 2.21236019e+01  2.21236019e+01  2.21236019e+01  2.21236019e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.21236019e+01  2.21236019e+01  2.21236019e+01  2.21236019e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.21236019e+01  2.21236019e+01  2.21236019e+01  2.21236019e+01
#    0.00000000e+00 -9.96871889e-01]
#  [ 2.21409321e+01  2.21409321e+01  2.21409321e+01  2.21409321e+01
#    1.10000000e+03 -9.83344615e-01]
#  [ 2.21409321e+01  2.21409321e+01  2.21409321e+01  2.21409321e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.21409321e+01  2.21409321e+01  2.21409321e+01  2.21409321e+01
#    0.00000000e+00 -9.96734560e-01]
#  [ 2.21409321e+01  2.21409321e+01  2.21409321e+01  2.21409321e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.21409321e+01  2.21409321e+01  2.21409321e+01  2.21409321e+01
#    0.00000000e+00 -9.96266802e-01]
#  [ 2.21409321e+01  2.21409321e+01  2.21409321e+01  2.21409321e+01
#    1.00000000e+02 -9.97794390e-01]
#  [ 2.21409321e+01  2.21409321e+01  2.21409321e+01  2.21409321e+01
#    0.00000000e+00 -9.98163044e-01]
#  [ 2.21409321e+01  2.21409321e+01  2.21409321e+01  2.21409321e+01
#    0.00000000e+00  9.25678015e-03]
#  [ 2.21409321e+01  2.21409321e+01  2.21409321e+01  2.21409321e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.21409321e+01  2.21409321e+01  2.21409321e+01  2.21409321e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.21409321e+01  2.21409321e+01  2.21409321e+01  2.21409321e+01
#    0.00000000e+00  9.85138834e-01]
#  [ 2.21409321e+01  2.21409321e+01  2.21409321e+01  2.21409321e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.21409321e+01  2.21409321e+01  2.21409321e+01  2.21409321e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.21409321e+01  2.21409321e+01  2.21409321e+01  2.21409321e+01
#    0.00000000e+00  9.99741137e-01]
#  [ 2.21409321e+01  2.21409321e+01  2.21409321e+01  2.21409321e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.21409321e+01  2.21409321e+01  2.21409321e+01  2.21409321e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.27562008e+01  2.27562008e+01  2.25222258e+01  2.25222258e+01
#    2.00000000e+02  0.00000000e+00]
#  [ 2.27562008e+01  2.27562008e+01  2.27562008e+01  2.27562008e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.27562008e+01  2.27562008e+01  2.27562008e+01  2.27562008e+01
#    0.00000000e+00 -9.90895450e-01]
#  [ 2.27562008e+01  2.27562008e+01  2.27562008e+01  2.27562008e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.29555092e+01  2.29555092e+01  2.29555092e+01  2.29555092e+01
#    8.00000000e+02  0.00000000e+00]
#  [ 2.29555092e+01  2.29555092e+01  2.29555092e+01  2.29555092e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.29555092e+01  2.29555092e+01  2.29555092e+01  2.29555092e+01
#    1.00000000e+02  0.00000000e+00]
#  [ 2.29555092e+01  2.29555092e+01  2.29555092e+01  2.29555092e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.29555092e+01  2.29555092e+01  2.29555092e+01  2.29555092e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.29555092e+01  2.29555092e+01  2.29555092e+01  2.29555092e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.29555092e+01  2.29555092e+01  2.29555092e+01  2.29555092e+01
#    0.00000000e+00 -9.94459391e-01]
#  [ 2.29555092e+01  2.29555092e+01  2.29555092e+01  2.29555092e+01
#    0.00000000e+00  0.00000000e+00]
#  [ 2.29555092e+01  2.29555092e+01  2.29555092e+01  2.29555092e+01
#    0.00000000e+00 -4.14467499e-01]
#  [ 2.36834316e+01  2.36834316e+01  2.34841203e+01  2.34841203e+01
#    1.70000000e+03  0.00000000e+00]
#  [ 2.37180958e+01  2.37180958e+01  2.37180958e+01  2.37180958e+01
#    2.00000000e+02  0.00000000e+00]
#  [ 2.34407902e+01  2.35274478e+01  2.34407902e+01  2.35049177e+01
#    3.90000000e+03  0.00000000e+00]
#  [ 2.33021374e+01  2.33021374e+01  2.33021374e+01  2.33021374e+01
#    2.00000000e+03  0.00000000e+00]]
#  [23.30213737]
# X size: (1987, 50, 6)
# y size: (1987, 1)

# %%
# 시퀀스별로 Min-Max 정규화
scaler = MinMaxScaler()
X_reshaped = X.reshape(-1, X.shape[-1])
X_scaled = scaler.fit_transform(X_reshaped).reshape(X.shape)
y_scaled = scaler.fit_transform(y)

# train, test 분리
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3, random_state=42)

# %% [markdown]
# ### 4.1 GRU

# %%
# 초기화 함수 정의
initializer = GlorotNormal()

# 모델 구성
model = Sequential()
model.add(BatchNormalization())
model.add(GRU(128, input_shape=(SEQ_SIZE, X_train.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(GRU(64, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu', kernel_initializer=initializer, kernel_regularizer=regularizers.l2(0.002)))
model.add(Dense(1))
optimizer = Adam(learning_rate=0.001)

model.compile(optimizer=optimizer, loss='mean_squared_error')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=EPOCH, validation_split=0.2, batch_size=BATCH_SIZE, callbacks=[early_stopping])

# 모델 평가
loss = model.evaluate(X_test, y_test)
print(f'테스트 손실: {loss}')

# 예측
y_pred = model.predict(X_test)
# Out:
# Epoch 1/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 79ms/step - loss: 0.2482 - val_loss: 0.1944
# Epoch 2/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.1288 - val_loss: 0.1982
# Epoch 3/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.1146 - val_loss: 0.1620
# Epoch 4/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.1010 - val_loss: 0.1574
# Epoch 5/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0885 - val_loss: 0.1550
# Epoch 6/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0807 - val_loss: 0.1253
# Epoch 7/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0752 - val_loss: 0.1151
# Epoch 8/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0699 - val_loss: 0.0898
# Epoch 9/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0646 - val_loss: 0.0727
# Epoch 10/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0630 - val_loss: 0.0752
# Epoch 11/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0588 - val_loss: 0.0534
# Epoch 12/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0543 - val_loss: 0.0500
# Epoch 13/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0518 - val_loss: 0.0443
# Epoch 14/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0472 - val_loss: 0.0402
# Epoch 15/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0448 - val_loss: 0.0399
# Epoch 16/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0431 - val_loss: 0.0357
# Epoch 17/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0393 - val_loss: 0.0335
# Epoch 18/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0364 - val_loss: 0.0316
# Epoch 19/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0339 - val_loss: 0.0319
# Epoch 20/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0331 - val_loss: 0.0292
# Epoch 21/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0310 - val_loss: 0.0266
# Epoch 22/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0286 - val_loss: 0.0258
# Epoch 23/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0276 - val_loss: 0.0234
# Epoch 24/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0262 - val_loss: 0.0231
# Epoch 25/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0245 - val_loss: 0.0204
# Epoch 26/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0236 - val_loss: 0.0197
# Epoch 27/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0233 - val_loss: 0.0190
# Epoch 28/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0207 - val_loss: 0.0166
# Epoch 29/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0203 - val_loss: 0.0168
# Epoch 30/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0186 - val_loss: 0.0157
# Restoring model weights from the end of the best epoch: 30.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0155
# 테스트 손실: 0.015485200099647045
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step

# %%
# 성능 평가 지표
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'MSE: {round(mse, 4)}')
print(f'MAE: {round(mae, 4)}')
# Out:
# MSE: 0.0014
# MAE: 0.0295

# %%
# 시각화
plt.figure(figsize=(36, 20))
plt.plot(y_test[100:300].flatten(), label='Actual')
plt.plot(y_pred[100:300].flatten(), label='Predicted')
plt.legend()
plt.title('Actual vs Predicted')
plt.show()

# 학습 곡선 시각화
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### 4.2 LSTM

# %%
# 시퀀스별로 Min-Max 정규화
scaler = MinMaxScaler()
X_reshaped = X.reshape(-1, X.shape[-1])
X_scaled = scaler.fit_transform(X_reshaped).reshape(X.shape)
y_scaled = scaler.fit_transform(y)
from tensorflow.keras import regularizers


# train, test 분리
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# 초기화 함수 정의
initializer = GlorotNormal()

# 모델 구성
model2 = Sequential()
model2.add(LSTM(128, input_shape=(SEQ_SIZE, X_train.shape[2]), return_sequences=True))
model2.add(Dropout(0.2))
model2.add(LSTM(64, return_sequences=False))
model2.add(Dropout(0.2))
model2.add(Dense(32, activation='relu', kernel_initializer=initializer, kernel_regularizer=regularizers.l2(0.002)))
model2.add(Dense(1))
optimizer = Adam(learning_rate=0.001)

model2.compile(optimizer=optimizer, loss='mean_squared_error')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
history = model2.fit(X_train, y_train, epochs=EPOCH, validation_split=0.2, batch_size=BATCH_SIZE, callbacks=[early_stopping])

# 모델 평가
loss = model2.evaluate(X_test, y_test)
print(f'테스트 손실: {loss}')

# 예측
y_pred = model2.predict(X_test)
# Out:
# Epoch 1/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - loss: 0.1091 - val_loss: 0.0667
# Epoch 2/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0646 - val_loss: 0.0520
# Epoch 3/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0492 - val_loss: 0.0385
# Epoch 4/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0369 - val_loss: 0.0294
# Epoch 5/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 0.0294 - val_loss: 0.0224
# Epoch 6/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0221 - val_loss: 0.0172
# Epoch 7/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0171 - val_loss: 0.0143
# Epoch 8/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0139 - val_loss: 0.0106
# Epoch 9/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0111 - val_loss: 0.0094
# Epoch 10/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0090 - val_loss: 0.0079
# Epoch 11/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0079 - val_loss: 0.0058
# Epoch 12/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0063 - val_loss: 0.0047
# Epoch 13/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0054 - val_loss: 0.0039
# Epoch 14/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 0.0045 - val_loss: 0.0054
# Epoch 15/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0048 - val_loss: 0.0031
# Epoch 16/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0036 - val_loss: 0.0025
# Epoch 17/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 18/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 19/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 20/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 21/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 22/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 23/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 24/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 25/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 26/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 27/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0016 - val_loss: 8.6820e-04
# Epoch 28/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0015 - val_loss: 7.6757e-04
# Epoch 29/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0013 - val_loss: 7.1205e-04
# Epoch 30/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0015 - val_loss: 7.4868e-04
# Restoring model weights from the end of the best epoch: 29.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.4895e-04
# 테스트 손실: 0.0007381227915175259
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step

# %%
# 성능 평가 지표
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'MSE: {round(mse, 4)}')
print(f'MAE: {round(mae, 4)}')
# Out:
# MSE: 0.0004
# MAE: 0.0151

# %%
# 시각화
plt.figure(figsize=(36, 20))
plt.plot(y_test.flatten(), label='Actual')
plt.plot(y_pred.flatten(), label='Predicted')
plt.legend()
plt.title('Actual vs Predicted')
plt.show()

# 학습 곡선 시각화
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## 5. 최종 모델 선정

# %% [markdown]
# MSE 값을 비교한 결과, LSTM의 성능이 더 좋은 것으로 보임.

# %%
# 테스트 데이터 예측
predicted_price = model2.predict(X_test)

# 원래 스케일로 변환
predicted_price = scaler.inverse_transform(predicted_price.reshape(-1, 1))
real_price = scaler.inverse_transform(y_test.reshape(-1, 1))

# 예측 결과 시각화
plt.figure(figsize=(36,20))
plt.plot(real_price, label='Actual Price')
plt.plot(predicted_price, label='Predicted Price')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
print(X_train.shape)  # (samples, SEQ_SIZE, features)
# Out:
# (1589, 50, 6)

# %%
future_days = 300  # 예측하고 싶은 미래 일 수
future_prices = []

recent_data = X_scaled[-SEQ_SIZE:].reshape(50, SEQ_SIZE, X_train.shape[2])

for i in range(future_days):
    predicted_price = model2.predict(recent_data)  # 하루 예측
    future_prices.append(predicted_price[0][0])  # 결과 저장

    # 예측된 값을 feature 차원에 맞춰 변환
    predicted_value = np.full((50, 1, X_train.shape[2]), predicted_price[0][0])  

    # 최근 데이터를 업데이트 (Sliding Window 방식)
    new_data = np.append(recent_data[:, 1:, :], predicted_value, axis=1)
    recent_data = new_data  # 최신 데이터로 갱신

# 원래 가격으로 변환
future_prices = scaler.inverse_transform(np.array(future_prices).reshape(-1, 1))
print(f"예측된 미래 {future_days}일 주가: {future_prices.flatten()}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#